# %% [markdown]
# Autor: Pablo Manresa Nebot.
#
# Entrenamiento de un modelo de few-shot learning con el algoritmo de MAML de primer orden para el dataset Omniglot.
#
#   **NOTA**: Usualmente este tipo de métodos suele ejecutarse durante unas 10.000 o 20.000 iteraciones, pero debido a las limitaciones técnicas, se ejecutarán unas pocas iteraciones para demostrar como poco a poco va aumentando su capacidad predictiva, pudiendo llegar para este problema en concreto a una exactitud cercana al 99.9% (con las suficientes iteraciones y reproduciendo los parámetros del artículo) para el problema de 5-way, 5-shot tal cual los autores definen en la propia publicación Model-Agnostic Meta-Learning for Fast Adaptation of Deep Networks (https://arxiv.org/abs/1703.03400)

# %%
# !pip install learn2learn
# Out:
# Requirement already satisfied: learn2learn in /usr/local/lib/python3.7/dist-packages (0.1.7)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from learn2learn) (1.21.6)
# Requirement already satisfied: gsutil in /usr/local/lib/python3.7/dist-packages (from learn2learn) (5.10)
# Requirement already satisfied: gym>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from learn2learn) (0.17.3)
# Requirement already satisfied: torchvision>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from learn2learn) (0.12.0+cu113)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from learn2learn) (4.64.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from learn2learn) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from learn2learn) (2.23.0)
# Requirement already satisfied: qpth>=0.0.15 in /usr/local/lib/python3.7/dist-packages (from learn2learn) (0.0.15)
# Requirement already satisfied: torch>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from learn2learn) (1.11.0+cu113)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym>=0.14.0->learn2learn) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym>=0.14.0->learn2learn) (1.5.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym>=0.14.0->learn2learn) (0.16.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.1.0->learn2learn) (4.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.3.0->learn2learn) (7.1.2)
# Requirement already satisfied: fasteners>=0.14.1 in /usr/local/lib/python3.7/dist-packages (from gsutil->learn2learn) (0.17.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from gsutil->learn2learn) (1.15.0)
# Requirement already satisfied: crcmod>=1.7 in /usr/local/lib/python3.7/dist-packages (from gsutil->learn2learn) (1.7)
# Requirement already satisfied: monotonic>=1.4 in /usr/local/lib/python3.7/dist-packages (from gsutil->learn2learn) (1.6)
# Requirement already satisfied: httplib2>=0.20.4 in /usr/local/lib/python3.7/dist-packages (from gsutil->learn2learn) (0.20.4)
# Requirement already satisfied: google-reauth>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from gsutil->learn2learn) (0.1.1)
# Requirement already satisfied: retry-decorator>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from gsutil->learn2learn) (1.1.1)
# Requirement already satisfied: google-auth[aiohttp]>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from gsutil->learn2learn) (2.6.6)
# Requirement already satisfied: gcs-oauth2-boto-plugin>=3.0 in /usr/local/lib/python3.7/dist-packages (from gsutil->learn2learn) (3.0)
# Requirement already satisfied: google-apitools>=0.5.32 in /usr/local/lib/python3.7/dist-packages (from gsutil->learn2learn) (0.5.32)
# Requirement already satisfied: pyOpenSSL>=0.13 in /usr/local/lib/python3.7/dist-packages (from gsutil->learn2learn) (22.0.0)
# Requirement already satisfied: argcomplete>=1.9.4 in /usr/local/lib/python3.7/dist-packages (from gsutil->learn2learn) (2.0.0)
# Requirement already satisfied: importlib-metadata<5,>=0.23 in /usr/local/lib/python3.7/dist-packages (from argcomplete>=1.9.4->gsutil->learn2learn) (4.11.3)
# Requirement already satisfied: boto>=2.29.1 in /usr/local/lib/python3.7/dist-packages (from gcs-oauth2-boto-plugin>=3.0->gsutil->learn2learn) (2.49.0)
# Requirement already satisfied: rsa==4.7.2 in /usr/local/lib/python3.7/dist-packages (from gcs-oauth2-boto-plugin>=3.0->gsutil->learn2learn) (4.7.2)
# Requirement already satisfied: oauth2client>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from gcs-oauth2-boto-plugin>=3.0->gsutil->learn2learn) (4.1.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa==4.7.2->gcs-oauth2-boto-plugin>=3.0->gsutil->learn2learn) (0.4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth[aiohttp]>=2.5.0->gsutil->learn2learn) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth[aiohttp]>=2.5.0->gsutil->learn2learn) (0.2.8)
# Requirement already satisfied: aiohttp<4.0.0dev,>=3.6.2 in /usr/local/lib/python3.7/dist-packages (from google-auth[aiohttp]>=2.5.0->gsutil->learn2learn) (3.8.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil->learn2learn) (2.0.12)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil->learn2learn) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil->learn2learn) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil->learn2learn) (21.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil->learn2learn) (1.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil->learn2learn) (6.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil->learn2learn) (0.13.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<4.0.0dev,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil->learn2learn) (1.7.2)
# Requirement already satisfied: pyu2f in /usr/local/lib/python3.7/dist-packages (from google-reauth>=0.1.0->gsutil->learn2learn) (0.1.5)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.7/dist-packages (from httplib2>=0.20.4->gsutil->learn2learn) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<5,>=0.23->argcomplete>=1.9.4->gsutil->learn2learn) (3.8.0)
# Requirement already satisfied: cryptography>=35.0 in /usr/local/lib/python3.7/dist-packages (from pyOpenSSL>=0.13->gsutil->learn2learn) (37.0.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=35.0->pyOpenSSL>=0.13->gsutil->learn2learn) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=35.0->pyOpenSSL>=0.13->gsutil->learn2learn) (2.21)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->learn2learn) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->learn2learn) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->learn2learn) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->learn2learn) (2.10)

# %% [markdown]
# Se cargan las librerías

# %%
import learn2learn as l2l
import numpy as np
import torch
import torchvision

# %% [markdown]
# Se definen los parámetros de carga del dataset para transformarlo en un problema de k-shot n-ways learning.

# %%
n_ways = 5
k_shots = 5
n_shots_tareas = 2*k_shots
num_tareas = 5000

# %% [markdown]
# Se carga el dataset Omniglot

# %%
tareas_omniglot = l2l.vision.benchmarks.get_tasksets('omniglot',
                                                  train_ways=n_ways,
                                                  train_samples=n_shots_tareas,
                                                  test_ways=n_ways,
                                                  test_samples=n_shots_tareas,
                                                  num_tasks=num_tareas,
                                                  root='~/datasets/omniglot',
    )
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:333: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# El siguiente paso, sería definir una red neuronal que actúe como extractor de características del dataset. Para ello está la opción de definir una red mediante Pytorch, o bien, usar una de las que provee **learn2learn** que está probado que proporcionan buenos resultados en dichos datasets. Por un lado está **OmniglotFC**, que es una red de tipo fully connected, y por otro **OmniglotCNN** que es una red convolucional. Se probará con **OmniglotCNN**. Para ello, el primer paso es definirla:

# %%
dispositivo = torch.device("cuda" if torch.cuda.is_available() else "cpu")
modelo = l2l.vision.models.OmniglotCNN(output_size=n_ways, hidden_size=128, layers=3)
modelo.to(dispositivo)
# Out:
# OmniglotCNN(
#   (base): ConvBase(
#     (0): ConvBlock(
#       (normalize): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (conv): Conv2d(1, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (1): ConvBlock(
#       (normalize): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (2): ConvBlock(
#       (normalize): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#   )
#   (features): Sequential(
#     (0): Lambda()
#     (1): ConvBase(
#       (0): ConvBlock(
#         (normalize): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv): Conv2d(1, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#       (1): ConvBlock(
#         (normalize): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#       (2): ConvBlock(
#         (normalize): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#     )
#     (2): Lambda()
#     (3): Flatten()
#   )
#   (classifier): Linear(in_features=128, out_features=5, bias=True)
# )

# %% [markdown]
# Dado que se usará el método **MAML**, se definirá junto a sus parámetros a continuación:

# %%
tam_paso_maml = 0.1
MAML = l2l.algorithms.MAML(modelo, tam_paso_maml, first_order=False)
MAML
# Out:
# MAML(
#   (module): OmniglotCNN(
#     (base): ConvBase(
#       (0): ConvBlock(
#         (normalize): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv): Conv2d(1, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#       (1): ConvBlock(
#         (normalize): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#       (2): ConvBlock(
#         (normalize): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#     )
#     (features): Sequential(
#       (0): Lambda()
#       (1): ConvBase(
#         (0): ConvBlock(
#           (normalize): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#           (conv): Conv2d(1, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#         (1): ConvBlock(
#           (normalize): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#         (2): ConvBlock(
#           (normalize): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#       (2): Lambda()
#       (3): Flatten()
#     )
#     (classifier): Linear(in_features=128, out_features=5, bias=True)
#   )
# )

# %% [markdown]
# Posteriormente se define el optimizador y la función de pérdida:

# %%
tam_paso_adam = 0.01

# Se define como pérdida la entropía cruzada
funcion_perdida = torch.nn.CrossEntropyLoss(reduction='mean')
optimizador = torch.optim.Adam(MAML.parameters(), lr = tam_paso_adam)

# %% [markdown]
# Antes de pasar a crear el bucle de entrenamiento, se tendrá que definir una función mediante la cual se produzca la adaptación a un nuevo conjunto de datos. Se definirá siguiendo la estructura sugerida por los mismos creadores de **learn2learn**.

# %%
def adaptacion(aprendiz, perdida, imagenes, etiquetas, etapas_adaptacion, k_shots, n_ways, dispositivo):
  imagenes, etiquetas = imagenes.to(dispositivo), etiquetas.to(dispositivo)

  indices_adaptacion = np.zeros(imagenes.size(0), dtype=bool)
  indices_seleccion = np.arange(k_shots * n_ways)*2
  indices_adaptacion[indices_seleccion] = True
  
  indices_evaluacion = torch.from_numpy(~indices_adaptacion)
  indices_adaptacion = torch.from_numpy(indices_adaptacion)

  imagenes_adaptacion = imagenes[indices_adaptacion]
  etiquetas_adaptacion = etiquetas[indices_adaptacion]

  for etapa_adaptacion in range(etapas_adaptacion):
    salida_aprendizaje = aprendiz(imagenes_adaptacion)
    error_train = perdida(salida_aprendizaje, etiquetas_adaptacion)
    aprendiz.adapt(error_train)

  imagenes_evaluacion = imagenes[indices_evaluacion]
  etiquetas_evaluacion = etiquetas[indices_evaluacion]

  predicciones = aprendiz(imagenes_evaluacion)
  error = perdida(predicciones, etiquetas_evaluacion)

  # Se calcula la exactitud
  exactitud = (predicciones.argmax(dim=1).view(etiquetas_evaluacion.shape) == etiquetas_evaluacion).sum().float() / etiquetas_evaluacion.size(0)

  return exactitud, error

# %% [markdown]
# El siguiente paso, sería definir el cuerpo de entrenamiento del algoritmo

# %%
def entrenamiento(MAML, tareas_omniglot, optimizador, funcion_perdida, dispositivo, config):
  iteraciones_entrenamiento = config["iteraciones_entrenamiento"]
  meta_batch = config["meta_batch"]
  iteraciones_adaptacion = config["iteraciones_adaptacion"]
  k_shots, n_ways = config["k_shots"], config["n_ways"]

  for iteracion in range(iteraciones_entrenamiento):
    # Se limpia la acumulación del gradiente de los pasos anteriores
    optimizador.zero_grad()

    error_meta_train = 0.0
    error_meta_val = 0.0
    exactitud_meta_train = 0.0
    exactitud_meta_val = 0.0

    for tarea in range(meta_batch):
      # Se define un aprendiz para el entrenamiento
      aprendiz = MAML.clone()
      batch_datos = tareas_omniglot.train.sample()
      imagenes, etiquetas = batch_datos

      exactitud, error = adaptacion(aprendiz, funcion_perdida, imagenes, etiquetas, iteraciones_adaptacion, k_shots, n_ways, dispositivo)
      
      error.backward()
      
      error_meta_train += error.item()
      exactitud_meta_train += exactitud.item()

      # Se define un aprendiz para la validación
      aprendiz = MAML.clone()
      batch_datos = tareas_omniglot.validation.sample()
      imagenes, etiquetas = batch_datos

      exactitud, error = adaptacion(aprendiz, funcion_perdida, imagenes, etiquetas, iteraciones_adaptacion, k_shots, n_ways, dispositivo)
      
      error_meta_val += error.item()
      exactitud_meta_val += exactitud.item()

    optimizador.step()
    if config["verbose"] == 1:
      print(f"Iteración {iteracion+1}")
      print(f"Error entrenamiento {error_meta_train/meta_batch}")
      print(f"Exactitud entrenamiento {exactitud_meta_train/meta_batch}")
      print(f"Error validación {error_meta_val/meta_batch}")
      print(f"Exactitud validación {exactitud_meta_val/meta_batch}")
      print("\n\n")
    elif iteracion % 10 == 0:
      print(f"Iteración {iteracion+1}")
      print(f"Error entrenamiento {error_meta_train/meta_batch}")
      print(f"Exactitud entrenamiento {exactitud_meta_train/meta_batch}")
      print(f"Error validación {error_meta_val/meta_batch}")
      print(f"Exactitud validación {exactitud_meta_val/meta_batch}")
      print("\n\n")

    # Se crea el bucle para el test
  error_meta_test, exactitud_meta_test = 0.0, 0.0
  for tarea in range(meta_batch):
    # Se define un aprendiz para el entrenamiento
    aprendiz = MAML.clone()
    batch_datos = tareas_omniglot.test.sample()
    imagenes, etiquetas = batch_datos

    exactitud, error = adaptacion(aprendiz, funcion_perdida, imagenes, etiquetas, iteraciones_adaptacion, k_shots, n_ways, dispositivo)
    
    error_meta_test += error.item()
    exactitud_meta_test += exactitud.item()

  print(f"Error test {error_meta_val/meta_batch}")
  print(f"Exactitud test {exactitud_meta_val/meta_batch}")


config = {}
config["iteraciones_entrenamiento"] = 120
config["meta_batch"] = 32
config["iteraciones_adaptacion"] = 1
config["k_shots"] = k_shots
config["n_ways"] = n_ways
config["verbose"] = 1

entrenamiento(MAML, tareas_omniglot, optimizador, funcion_perdida, dispositivo, config)
# Out:
# Iteración 1
# Error entrenamiento 1.2005705144256353
# Exactitud entrenamiento 0.487499987706542
# Error validación 1.249436704441905
# Exactitud validación 0.48124998807907104
#
#
#
# Iteración 2
# Error entrenamiento 1.241730224341154
# Exactitud entrenamiento 0.4812499862164259
# Error validación 1.2649349141865969
# Exactitud validación 0.4812499904073775
#
#
#
# Iteración 3
# Error entrenamiento 1.1567829865962267
# Exactitud entrenamiento 0.5474999882280827
# Error validación 1.217702740803361
# Exactitud validación 0.5124999838881195
#
#
#
# Iteración 4
# Error entrenamiento 1.1596728879958391
# Exactitud entrenamiento 0.5299999862909317
# Error validación 1.1848582196980715
# Exactitud validación 0.4962499886751175
#
#
#
# Iteración 5
# Error entrenamiento 1.2322745230048895
# Exactitud entrenamiento 0.49624998681247234
# Error validación 1.2517653685063124
# Exactitud validación 0.4637499861419201
#
#
#
# Iteración 6
# Error entrenamiento 1.1863464582711458
# Exactitud entrenamiento 0.49124998645856977
# Error validación 1.244258714839816
# Exactitud validación 0.47374998591840267
#
#
#
# Iteración 7
# Error entrenamiento 1.2476206440478563
# Exactitud entrenamiento 0.47999998554587364
# Error validación 1.1735303290188313
# Exactitud validación 0.5249999854713678
#
#
#
# Iteración 8
# Error entrenamiento 1.203307144343853
# Exactitud entrenamiento 0.4937499864026904
# Error validación 1.209353681653738
# Exactitud validación 0.4824999854899943
#
#
#
# Iteración 9
# Error entrenamiento 1.2496598362922668
# Exactitud entrenamiento 0.48749998584389687
# Error validación 1.1555622275918722
# Exactitud validación 0.5174999879673123
#
#
#
# Iteración 10
# Error entrenamiento 1.2164132222533226
# Exactitud entrenamiento 0.49624998681247234
# Error validación 1.263690061867237
# Exactitud validación 0.47124999202787876
#
#
#
# Iteración 11
# Error entrenamiento 1.186482248827815
# Exactitud entrenamiento 0.5174999916926026
# Error validación 1.1726247072219849
# Exactitud validación 0.5212499862536788
#
#
#
# Iteración 12
# Error entrenamiento 1.1255610976368189
# Exactitud entrenamiento 0.5399999869987369
# Error validación 1.1328076850622892
# Exactitud validación 0.554999987129122
#
#
#
# Iteración 13
# Error entrenamiento 1.2529406026005745
# Exactitud entrenamiento 0.4899999834597111
# Error validación 1.1207911558449268
# Exactitud validación 0.5324999848380685
#
#
#
# Iteración 14
# Error entrenamiento 1.2637823186814785
# Exactitud entrenamiento 0.47124999249354005
# Error validación 1.2537442315369844
# Exactitud validación 0.457499987911433
#
#
#
# Iteración 15
# Error entrenamiento 1.2378899212926626
# Exactitud entrenamiento 0.4837499880231917
# Error validación 1.2198501955717802
# Exactitud validación 0.47499998519197106
#
#
#
# Iteración 16
# Error entrenamiento 1.2670924942940474
# Exactitud entrenamiento 0.4387499880976975
# Error validación 1.254224805161357
# Exactitud validación 0.49249998666346073
#
#
#
# Iteración 17
# Error entrenamiento 1.1971669420599937
# Exactitud entrenamiento 0.49749998934566975
# Error validación 1.2935113236308098
# Exactitud validación 0.4562499886378646
#
#
#
# Iteración 18
# Error entrenamiento 1.261154267936945
# Exactitud entrenamiento 0.4762499858625233
# Error validación 1.2660159338265657
# Exactitud validación 0.4624999868683517
#
#
#
# Iteración 19
# Error entrenamiento 1.1807927023619413
# Exactitud entrenamiento 0.5212499871850014
# Error validación 1.2101332731544971
# Exactitud validación 0.49499999172985554
#
#
#
# Iteración 20
# Error entrenamiento 1.1683903615921736
# Exactitud entrenamiento 0.5112499864771962
# Error validación 1.1917043812572956
# Exactitud validación 0.5037499880418181
#
#
#
# Iteración 21
# Error entrenamiento 1.294948223978281
# Exactitud entrenamiento 0.4637499894015491
# Error validación 1.3094342444092035
# Exactitud validación 0.4599999859929085
#
#
#
# Iteración 22
# Error entrenamiento 1.1980729196220636
# Exactitud entrenamiento 0.5074999900534749
# Error validación 1.2135205157101154
# Exactitud validación 0.5087499851360917
#
#
#
# Iteración 23
# Error entrenamiento 1.1692710146307945
# Exactitud entrenamiento 0.5212499890476465
# Error validación 1.1988328099250793
# Exactitud validación 0.4874999849125743
#
#
#
# Iteración 24
# Error entrenamiento 1.1495432071387768
# Exactitud entrenamiento 0.5062499912455678
# Error validación 1.1682845670729876
# Exactitud validación 0.49999998789280653
#
#
#
# Iteración 25
# Error entrenamiento 1.1351282335817814
# Exactitud entrenamiento 0.5249999882653356
# Error validación 1.1821558382362127
# Exactitud validación 0.5149999903514981
#
#
#
# Iteración 26
# Error entrenamiento 1.1799858622252941
# Exactitud entrenamiento 0.5037499857135117
# Error validación 1.2275890950113535
# Exactitud validación 0.48999998485669494
#
#
#
# Iteración 27
# Error entrenamiento 1.195539878681302
# Exactitud entrenamiento 0.4924999913200736
# Error validación 1.2083308100700378
# Exactitud validación 0.4899999890476465
#
#
#
# Iteración 28
# Error entrenamiento 1.185449717566371
# Exactitud entrenamiento 0.5112499888055027
# Error validación 1.2424094881862402
# Exactitud validación 0.4837499870918691
#
#
#
# Iteración 29
# Error entrenamiento 1.2081449571996927
# Exactitud entrenamiento 0.5187499872408807
# Error validación 1.2202537022531033
# Exactitud validación 0.5037499857135117
#
#
#
# Iteración 30
# Error entrenamiento 1.2206079959869385
# Exactitud entrenamiento 0.49499998637475073
# Error validación 1.2160438988357782
# Exactitud validación 0.48749998677521944
#
#
#
# Iteración 31
# Error entrenamiento 1.1747919470071793
# Exactitud entrenamiento 0.523749983869493
# Error validación 1.1635493133217096
# Exactitud validación 0.5212499811314046
#
#
#
# Iteración 32
# Error entrenamiento 1.1860321611166
# Exactitud entrenamiento 0.503749986179173
# Error validación 1.266887640580535
# Exactitud validación 0.4837499903514981
#
#
#
# Iteración 33
# Error entrenamiento 1.1485669761896133
# Exactitud entrenamiento 0.5274999854154885
# Error validación 1.1214812342077494
# Exactitud validación 0.5499999821186066
#
#
#
# Iteración 34
# Error entrenamiento 1.1258661858737469
# Exactitud entrenamiento 0.5312499832361937
# Error validación 1.1467278748750687
# Exactitud validación 0.5199999893084168
#
#
#
# Iteración 35
# Error entrenamiento 1.0956220664083958
# Exactitud entrenamiento 0.5524999834597111
# Error validación 1.07038052380085
# Exactitud validación 0.5637499885633588
#
#
#
# Iteración 36
# Error entrenamiento 1.1429487373679876
# Exactitud entrenamiento 0.5487499865703285
# Error validación 1.110303083434701
# Exactitud validación 0.5337499831803143
#
#
#
# Iteración 37
# Error entrenamiento 1.0747232045978308
# Exactitud entrenamiento 0.5387499858625233
# Error validación 1.070644035935402
# Exactitud validación 0.5674999924376607
#
#
#
# Iteración 38
# Error entrenamiento 1.1810160297900438
# Exactitud entrenamiento 0.5124999913387001
# Error validación 1.119108535349369
# Exactitud validación 0.534999986179173
#
#
#
# Iteración 39
# Error entrenamiento 1.0649188049137592
# Exactitud entrenamiento 0.5749999904073775
# Error validación 1.1387643069028854
# Exactitud validación 0.5424999874085188
#
#
#
# Iteración 40
# Error entrenamiento 1.1574213448911905
# Exactitud entrenamiento 0.5099999904632568
# Error validación 1.0877958722412586
# Exactitud validación 0.562499986961484
#
#
#
# Iteración 41
# Error entrenamiento 1.1044862121343613
# Exactitud entrenamiento 0.5524999848566949
# Error validación 1.0723559502512217
# Exactitud validación 0.5562499854713678
#
#
#
# Iteración 42
# Error entrenamiento 0.9968567993491888
# Exactitud entrenamiento 0.5874999798834324
# Error validación 1.1142426896840334
# Exactitud validación 0.5499999858438969
#
#
#
# Iteración 43
# Error entrenamiento 1.1400092262774706
# Exactitud entrenamiento 0.5512499865144491
# Error validación 1.063668241724372
# Exactitud validación 0.5649999873712659
#
#
#
# Iteración 44
# Error entrenamiento 1.1490217745304108
# Exactitud entrenamiento 0.5212499862536788
# Error validación 1.0822788178920746
# Exactitud validación 0.562499983003363
#
#
#
# Iteración 45
# Error entrenamiento 1.0968280732631683
# Exactitud entrenamiento 0.5287499856203794
# Error validación 1.0952568296343088
# Exactitud validación 0.5399999832734466
#
#
#
# Iteración 46
# Error entrenamiento 1.06626383587718
# Exactitud entrenamiento 0.569999985396862
# Error validación 1.0585020557045937
# Exactitud validación 0.5524999904446304
#
#
#
# Iteración 47
# Error entrenamiento 1.0081271436065435
# Exactitud entrenamiento 0.5699999826028943
# Error validación 1.1100565642118454
# Exactitud validación 0.5287499837577343
#
#
#
# Iteración 48
# Error entrenamiento 1.077802510932088
# Exactitud entrenamiento 0.5624999878928065
# Error validación 1.0401808023452759
# Exactitud validación 0.5474999845027924
#
#
#
# Iteración 49
# Error entrenamiento 0.978976970538497
# Exactitud entrenamiento 0.6087499847635627
# Error validación 1.0061151124536991
# Exactitud validación 0.6099999854341149
#
#
#
# Iteración 50
# Error entrenamiento 1.0548799261450768
# Exactitud entrenamiento 0.5637499829754233
# Error validación 1.0621904581785202
# Exactitud validación 0.5474999900907278
#
#
#
# Iteración 51
# Error entrenamiento 1.0364232771098614
# Exactitud entrenamiento 0.5749999890103936
# Error validación 1.0498297372832894
# Exactitud validación 0.5812499839812517
#
#
#
# Iteración 52
# Error entrenamiento 1.0331265423446894
# Exactitud entrenamiento 0.5699999863281846
# Error validación 1.0544113172218204
# Exactitud validación 0.5949999857693911
#
#
#
# Iteración 53
# Error entrenamiento 0.9883700255304575
# Exactitud entrenamiento 0.6037499886006117
# Error validación 1.0152541529387236
# Exactitud validación 0.5974999852478504
#
#
#
# Iteración 54
# Error entrenamiento 1.0972834806889296
# Exactitud entrenamiento 0.5762499854899943
# Error validación 1.0597655158489943
# Exactitud validación 0.5774999847635627
#
#
#
# Iteración 55
# Error entrenamiento 0.9840508829802275
# Exactitud entrenamiento 0.5899999877437949
# Error validación 1.0595936439931393
# Exactitud validación 0.5499999830499291
#
#
#
# Iteración 56
# Error entrenamiento 0.9682997725903988
# Exactitud entrenamiento 0.601249985396862
# Error validación 1.0537792276591063
# Exactitud validación 0.5699999891221523
#
#
#
# Iteración 57
# Error entrenamiento 1.0417512319982052
# Exactitud entrenamiento 0.5862499885261059
# Error validación 0.9950817283242941
# Exactitud validación 0.5949999867007136
#
#
#
# Iteración 58
# Error entrenamiento 0.9436635375022888
# Exactitud entrenamiento 0.6237499862909317
# Error validación 0.9524686764925718
# Exactitud validación 0.6337499925866723
#
#
#
# Iteración 59
# Error entrenamiento 1.005412394180894
# Exactitud entrenamiento 0.6074999943375587
# Error validación 1.0258655156940222
# Exactitud validación 0.5874999845400453
#
#
#
# Iteración 60
# Error entrenamiento 0.9223091397434473
# Exactitud entrenamiento 0.6362499855458736
# Error validación 0.9872542023658752
# Exactitud validación 0.5987499849870801
#
#
#
# Iteración 61
# Error entrenamiento 1.02138133905828
# Exactitud entrenamiento 0.5724999839439988
# Error validación 0.9889638246968389
# Exactitud validación 0.6012499835342169
#
#
#
# Iteración 62
# Error entrenamiento 1.031121278181672
# Exactitud entrenamiento 0.5799999870359898
# Error validación 0.9464433509856462
# Exactitud validación 0.6062499843537807
#
#
#
# Iteración 63
# Error entrenamiento 0.9953231643885374
# Exactitud entrenamiento 0.5999999847263098
# Error validación 0.9680606815963984
# Exactitud validación 0.6012499835342169
#
#
#
# Iteración 64
# Error entrenamiento 0.9548418987542391
# Exactitud entrenamiento 0.629999983124435
# Error validación 0.9663253035396338
# Exactitud validación 0.6112499861046672
#
#
#
# Iteración 65
# Error entrenamiento 1.013407288119197
# Exactitud entrenamiento 0.5612499872222543
# Error validación 1.0761879943311214
# Exactitud validación 0.5649999817833304
#
#
#
# Iteración 66
# Error entrenamiento 0.9975505322217941
# Exactitud entrenamiento 0.5937499850988388
# Error validación 1.0226343981921673
# Exactitud validación 0.5862499801442027
#
#
#
# Iteración 67
# Error entrenamiento 0.9217603616416454
# Exactitud entrenamiento 0.6299999821931124
# Error validación 0.979571595788002
# Exactitud validación 0.6037499848753214
#
#
#
# Iteración 68
# Error entrenamiento 0.9339947365224361
# Exactitud entrenamiento 0.6224999856203794
# Error validación 0.9086700463667512
# Exactitud validación 0.6212499886751175
#
#
#
# Iteración 69
# Error entrenamiento 0.9972000531852245
# Exactitud entrenamiento 0.5849999850615859
# Error validación 1.0362168923020363
# Exactitud validación 0.5687499889172614
#
#
#
# Iteración 70
# Error entrenamiento 0.9666465483605862
# Exactitud entrenamiento 0.6112499833106995
# Error validación 1.0169254411011934
# Exactitud validación 0.6012499835342169
#
#
#
# Iteración 71
# Error entrenamiento 0.9221978886052966
# Exactitud entrenamiento 0.623749983496964
# Error validación 1.0058945454657078
# Exactitud validación 0.6112499833106995
#
#
#
# Iteración 72
# Error entrenamiento 0.9539922121912241
# Exactitud entrenamiento 0.6162499859929085
# Error validación 1.0418518893420696
# Exactitud validación 0.5824999841861427
#
#
#
# Iteración 73
# Error entrenamiento 0.9591385526582599
# Exactitud entrenamiento 0.6162499915808439
# Error validación 0.9645151402801275
# Exactitud validación 0.6262499811127782
#
#
#
# Iteración 74
# Error entrenamiento 0.893387395888567
# Exactitud entrenamiento 0.6449999809265137
# Error validación 0.9677474461495876
# Exactitud validación 0.6137499827891588
#
#
#
# Iteración 75
# Error entrenamiento 0.9492283519357443
# Exactitud entrenamiento 0.5874999854713678
# Error validación 0.9201310761272907
# Exactitud validación 0.6312499893829226
#
#
#
# Iteración 76
# Error entrenamiento 0.8666295241564512
# Exactitud entrenamiento 0.6524999802932143
# Error validación 0.9471960756927729
# Exactitud validación 0.6312499847263098
#
#
#
# Iteración 77
# Error entrenamiento 0.9770191852003336
# Exactitud entrenamiento 0.6212499840185046
# Error validación 0.9379604011774063
# Exactitud validación 0.644999984651804
#
#
#
# Iteración 78
# Error entrenamiento 0.9333461243659258
# Exactitud entrenamiento 0.6212499849498272
# Error validación 0.9847432933747768
# Exactitud validación 0.5999999865889549
#
#
#
# Iteración 79
# Error entrenamiento 0.8891170639544725
# Exactitud entrenamiento 0.6312499865889549
# Error validación 0.9441689364612103
# Exactitud validación 0.6362499790266156
#
#
#
# Iteración 80
# Error entrenamiento 0.9287380650639534
# Exactitud entrenamiento 0.6349999848753214
# Error validación 0.9340202435851097
# Exactitud validación 0.6274999845772982
#
#
#
# Iteración 81
# Error entrenamiento 0.9259038437157869
# Exactitud entrenamiento 0.6249999850988388
# Error validación 0.908379121683538
# Exactitud validación 0.632499985396862
#
#
#
# Iteración 82
# Error entrenamiento 0.927822956815362
# Exactitud entrenamiento 0.6274999864399433
# Error validación 0.8758312193676829
# Exactitud validación 0.6512499842792749
#
#
#
# Iteración 83
# Error entrenamiento 0.9527926910668612
# Exactitud entrenamiento 0.5987499877810478
# Error validación 0.9194659758359194
# Exactitud validación 0.6324999835342169
#
#
#
# Iteración 84
# Error entrenamiento 0.9237201968207955
# Exactitud entrenamiento 0.6162499878555536
# Error validación 0.9176601525396109
# Exactitud validación 0.6412499882280827
#
#
#
# Iteración 85
# Error entrenamiento 0.9451471343636513
# Exactitud entrenamiento 0.6187499854713678
# Error validación 0.9361663199961185
# Exactitud validación 0.6362499874085188
#
#
#
# Iteración 86
# Error entrenamiento 0.87105618044734
# Exactitud entrenamiento 0.6487499820068479
# Error validación 0.9170429278165102
# Exactitud validación 0.6362499827519059
#
#
#
# Iteración 87
# Error entrenamiento 0.9012075643986464
# Exactitud entrenamiento 0.6287499833852053
# Error validación 0.8977758418768644
# Exactitud validación 0.6524999802932143
#
#
#
# Iteración 88
# Error entrenamiento 0.952547300606966
# Exactitud entrenamiento 0.6287499843165278
# Error validación 0.9176311679184437
# Exactitud validación 0.6424999828450382
#
#
#
# Iteración 89
# Error entrenamiento 0.9146462697535753
# Exactitud entrenamiento 0.6274999855086207
# Error validación 0.8207437070086598
# Exactitud validación 0.668749988079071
#
#
#
# Iteración 90
# Error entrenamiento 0.8722749929875135
# Exactitud entrenamiento 0.6462499788030982
# Error validación 0.9026044812053442
# Exactitud validación 0.6349999830126762
#
#
#
# Iteración 91
# Error entrenamiento 0.9230603016912937
# Exactitud entrenamiento 0.6362499799579382
# Error validación 0.8652899861335754
# Exactitud validación 0.6499999836087227
#
#
#
# Iteración 92
# Error entrenamiento 0.8703236356377602
# Exactitud entrenamiento 0.6562499795109034
# Error validación 0.9715145770460367
# Exactitud validación 0.6074999840930104
#
#
#
# Iteración 93
# Error entrenamiento 0.9722820371389389
# Exactitud entrenamiento 0.6462499806657434
# Error validación 0.8455762006342411
# Exactitud validación 0.658749982714653
#
#
#
# Iteración 94
# Error entrenamiento 0.9793332070112228
# Exactitud entrenamiento 0.6099999845027924
# Error validación 0.9515721257776022
# Exactitud validación 0.6387499822303653
#
#
#
# Iteración 95
# Error entrenamiento 0.8945268085226417
# Exactitud entrenamiento 0.6374999852851033
# Error validación 0.9272244852036238
# Exactitud validación 0.6362499790266156
#
#
#
# Iteración 96
# Error entrenamiento 0.9372880887240171
# Exactitud entrenamiento 0.6037499830126762
# Error validación 0.8761540362611413
# Exactitud validación 0.6274999836459756
#
#
#
# Iteración 97
# Error entrenamiento 0.9417263688519597
# Exactitud entrenamiento 0.6399999782443047
# Error validación 0.9083686377853155
# Exactitud validación 0.6474999841302633
#
#
#
# Iteración 98
# Error entrenamiento 0.8883737456053495
# Exactitud entrenamiento 0.6374999824911356
# Error validación 0.9325086260214448
# Exactitud validación 0.6224999856203794
#
#
#
# Iteración 99
# Error entrenamiento 0.8789353426545858
# Exactitud entrenamiento 0.6599999824538827
# Error validación 0.8762603048235178
# Exactitud validación 0.6537499902769923
#
#
#
# Iteración 100
# Error entrenamiento 0.8428892279043794
# Exactitud entrenamiento 0.679999983869493
# Error validación 0.8922307174652815
# Exactitud validación 0.6599999843165278
#
#
#
# Iteración 101
# Error entrenamiento 0.927422909066081
# Exactitud entrenamiento 0.6187499845400453
# Error validación 0.8534999908879399
# Exactitud validación 0.6824999842792749
#
#
#
# Iteración 102
# Error entrenamiento 0.8743673423305154
# Exactitud entrenamiento 0.6449999837204814
# Error validación 0.8908486589789391
# Exactitud validación 0.6537499828264117
#
#
#
# Iteración 103
# Error entrenamiento 0.9424060080200434
# Exactitud entrenamiento 0.6224999828264117
# Error validación 0.940306437201798
# Exactitud validación 0.6112499870359898
#
#
#
# Iteración 104
# Error entrenamiento 0.8604070600122213
# Exactitud entrenamiento 0.6662499876692891
# Error validación 0.8600507415831089
# Exactitud validación 0.684999980032444
#
#
#
# Iteración 105
# Error entrenamiento 0.8685819646343589
# Exactitud entrenamiento 0.6362499846145511
# Error validación 0.9275550870224833
# Exactitud validación 0.6349999830126762
#
#
#
# Iteración 106
# Error entrenamiento 0.8481805622577667
# Exactitud entrenamiento 0.6687499759718776
# Error validación 0.8936521969735622
# Exactitud validación 0.6449999837204814
#
#
#
# Iteración 107
# Error entrenamiento 0.8822758523747325
# Exactitud entrenamiento 0.6537499818950891
# Error validación 0.914934498257935
# Exactitud validación 0.6362499846145511
#
#
#
# Iteración 108
# Error entrenamiento 0.8595442567020655
# Exactitud entrenamiento 0.6762499827891588
# Error validación 0.8386224564164877
# Exactitud validación 0.6737499823793769
#
#
#
# Iteración 109
# Error entrenamiento 0.7548130080103874
# Exactitud entrenamiento 0.7024999829009175
# Error validación 0.9084407947957516
# Exactitud validación 0.6512499824166298
#
#
#
# Iteración 110
# Error entrenamiento 0.8397506549954414
# Exactitud entrenamiento 0.6699999878183007
# Error validación 0.8985213013365865
# Exactitud validación 0.6662499820813537
#
#
#
# Iteración 111
# Error entrenamiento 0.8660689862444997
# Exactitud entrenamiento 0.6699999840930104
# Error validación 0.8163752034306526
# Exactitud validación 0.6649999842047691
#
#
#
# Iteración 112
# Error entrenamiento 0.85110242664814
# Exactitud entrenamiento 0.6799999829381704
# Error validación 0.895406206138432
# Exactitud validación 0.658749982714653
#
#
#
# Iteración 113
# Error entrenamiento 0.8283631131052971
# Exactitud entrenamiento 0.6887499857693911
# Error validación 0.8874534461647272
# Exactitud validación 0.6562499823048711
#
#
#
# Iteración 114
# Error entrenamiento 0.7248791344463825
# Exactitud entrenamiento 0.7224999815225601
# Error validación 0.8030658615753055
# Exactitud validación 0.6887499773874879
#
#
#
# Iteración 115
# Error entrenamiento 0.8374899094924331
# Exactitud entrenamiento 0.6599999852478504
# Error validación 0.9157764138653874
# Exactitud validación 0.6374999824911356
#
#
#
# Iteración 116
# Error entrenamiento 0.8484765291213989
# Exactitud entrenamiento 0.6612499868497252
# Error validación 0.8652814598754048
# Exactitud validación 0.6562499841675162
#
#
#
# Iteración 117
# Error entrenamiento 0.8881922271102667
# Exactitud entrenamiento 0.6574999801814556
# Error validación 0.8379856748506427
# Exactitud validación 0.689999982714653
#
#
#
# Iteración 118
# Error entrenamiento 0.8466693228110671
# Exactitud entrenamiento 0.6637499835342169
# Error validación 0.8425761517137289
# Exactitud validación 0.6812499864026904
#
#
#
# Iteración 119
# Error entrenamiento 0.779197751544416
# Exactitud entrenamiento 0.6912499852478504
# Error validación 0.8258601408451796
# Exactitud validación 0.6662499802187085
#
#
#
# Iteración 120
# Error entrenamiento 0.7940666358917952
# Exactitud entrenamiento 0.6837499793618917
# Error validación 0.9193709986284375
# Exactitud validación 0.6237499825656414
#
#
#
# Error test 0.9193709986284375
# Exactitud test 0.6237499825656414

# %% [markdown]
# Ahora se probará con un MAML de primer orden, y se comprobará si para el mismo número de iteraciones produce un resultado similar

# %%
config = {}
config["iteraciones_entrenamiento"] = 120
config["meta_batch"] = 32
config["iteraciones_adaptacion"] = 1
config["k_shots"] = k_shots
config["n_ways"] = n_ways
config["verbose"] = 1

tam_paso_maml = 0.1
MAML_1st = l2l.algorithms.MAML(modelo, tam_paso_maml, first_order=True)

tam_paso_adam = 0.01

# Se define como pérdida la entropía cruzada
funcion_perdida = torch.nn.CrossEntropyLoss(reduction='mean')

# Se define el optimizador
optimizador_1st = torch.optim.Adam(MAML_1st.parameters(), lr = tam_paso_adam)

entrenamiento(MAML_1st, tareas_omniglot, optimizador_1st, funcion_perdida, dispositivo, config)
# Out:
# Iteración 1
# Error entrenamiento 0.8091871570795774
# Exactitud entrenamiento 0.6762499809265137
# Error validación 0.8850087765604258
# Exactitud validación 0.6374999824911356
#
#
#
# Iteración 2
# Error entrenamiento 0.8862967006862164
# Exactitud entrenamiento 0.6574999839067459
# Error validación 0.8774734847247601
# Exactitud validación 0.6412499845027924
#
#
#
# Iteración 3
# Error entrenamiento 0.8250762289389968
# Exactitud entrenamiento 0.6662499848753214
# Error validación 0.8993904097005725
# Exactitud validación 0.6562499832361937
#
#
#
# Iteración 4
# Error entrenamiento 0.812625671736896
# Exactitud entrenamiento 0.6837499858811498
# Error validación 0.9323175195604563
# Exactitud validación 0.6337499814108014
#
#
#
# Iteración 5
# Error entrenamiento 0.7911419626325369
# Exactitud entrenamiento 0.6762499855831265
# Error validación 0.8507546801120043
# Exactitud validación 0.6549999816343188
#
#
#
# Iteración 6
# Error entrenamiento 0.8265849584713578
# Exactitud entrenamiento 0.6674999776296318
# Error validación 0.9569445475935936
# Exactitud validación 0.6124999821186066
#
#
#
# Iteración 7
# Error entrenamiento 0.8830834105610847
# Exactitud entrenamiento 0.669999985024333
# Error validación 0.8453842233866453
# Exactitud validación 0.6524999774992466
#
#
#
# Iteración 8
# Error entrenamiento 0.8815223211422563
# Exactitud entrenamiento 0.6812499798834324
# Error validación 0.8507913323119283
# Exactitud validación 0.6699999831616879
#
#
#
# Iteración 9
# Error entrenamiento 0.8940298845991492
# Exactitud entrenamiento 0.6274999864399433
# Error validación 0.9039753992110491
# Exactitud validación 0.6412499872967601
#
#
#
# Iteración 10
# Error entrenamiento 0.8574196919798851
# Exactitud entrenamiento 0.6562499850988388
# Error validación 0.9379790928214788
# Exactitud validación 0.6037499830126762
#
#
#
# Iteración 11
# Error entrenamiento 0.9171179244294763
# Exactitud entrenamiento 0.6087499866262078
# Error validación 0.9940100032836199
# Exactitud validación 0.5874999864026904
#
#
#
# Iteración 12
# Error entrenamiento 0.854990835301578
# Exactitud entrenamiento 0.6487499829381704
# Error validación 0.8683281745761633
# Exactitud validación 0.6649999860674143
#
#
#
# Iteración 13
# Error entrenamiento 0.8670367049053311
# Exactitud entrenamiento 0.648749983869493
# Error validación 0.8417859552428126
# Exactitud validación 0.6399999847635627
#
#
#
# Iteración 14
# Error entrenamiento 0.8925839047878981
# Exactitud entrenamiento 0.6512499833479524
# Error validación 0.8152496488764882
# Exactitud validación 0.6799999848008156
#
#
#
# Iteración 15
# Error entrenamiento 0.8875617403537035
# Exactitud entrenamiento 0.6324999826028943
# Error validación 0.8409648360684514
# Exactitud validación 0.6587499789893627
#
#
#
# Iteración 16
# Error entrenamiento 0.9222018513828516
# Exactitud entrenamiento 0.6437499867752194
# Error validación 0.9145392933860421
# Exactitud validación 0.6462499834597111
#
#
#
# Iteración 17
# Error entrenamiento 0.836671962402761
# Exactitud entrenamiento 0.6724999863654375
# Error validación 0.7988248411566019
# Exactitud validación 0.678749980404973
#
#
#
# Iteración 18
# Error entrenamiento 0.8188598090782762
# Exactitud entrenamiento 0.6649999832734466
# Error validación 0.8813709942623973
# Exactitud validación 0.6499999789521098
#
#
#
# Iteración 19
# Error entrenamiento 0.8460733452811837
# Exactitud entrenamiento 0.669999985024333
# Error validación 0.8979688193649054
# Exactitud validación 0.642499984242022
#
#
#
# Iteración 20
# Error entrenamiento 0.8105535879731178
# Exactitud entrenamiento 0.6874999795109034
# Error validación 0.8314041141420603
# Exactitud validación 0.6624999856576324
#
#
#
# Iteración 21
# Error entrenamiento 0.8271256312727928
# Exactitud entrenamiento 0.668749981559813
# Error validación 0.8573791310191154
# Exactitud validación 0.6737499823793769
#
#
#
# Iteración 22
# Error entrenamiento 0.79764848574996
# Exactitud entrenamiento 0.6912499843165278
# Error validación 0.7912993524223566
# Exactitud validación 0.6749999821186066
#
#
#
# Iteración 23
# Error entrenamiento 0.7669048877432942
# Exactitud entrenamiento 0.6974999764934182
# Error validación 0.8109786473214626
# Exactitud validación 0.6699999822303653
#
#
#
# Iteración 24
# Error entrenamiento 0.8792556002736092
# Exactitud entrenamiento 0.6612499812617898
# Error validación 0.7916926583275199
# Exactitud validación 0.6649999832734466
#
#
#
# Iteración 25
# Error entrenamiento 0.82808808516711
# Exactitud entrenamiento 0.683749983087182
# Error validación 0.9029704425483942
# Exactitud validación 0.6387499840930104
#
#
#
# Iteración 26
# Error entrenamiento 0.8015736220404506
# Exactitud entrenamiento 0.6862499816343188
# Error validación 0.8697519768029451
# Exactitud validación 0.651249990798533
#
#
#
# Iteración 27
# Error entrenamiento 0.7345105912536383
# Exactitud entrenamiento 0.7024999838322401
# Error validación 0.7834119703620672
# Exactitud validación 0.6974999774247408
#
#
#
# Iteración 28
# Error entrenamiento 0.8095802422612906
# Exactitud entrenamiento 0.6699999822303653
# Error validación 0.8306847056373954
# Exactitud validación 0.6762499874457717
#
#
#
# Iteración 29
# Error entrenamiento 0.8301220154389739
# Exactitud entrenamiento 0.683749983087182
# Error validación 0.8307204777374864
# Exactitud validación 0.6599999852478504
#
#
#
# Iteración 30
# Error entrenamiento 0.7976578446105123
# Exactitud entrenamiento 0.7024999829009175
# Error validación 0.8398957010358572
# Exactitud validación 0.6574999811127782
#
#
#
# Iteración 31
# Error entrenamiento 0.7544220080599189
# Exactitud entrenamiento 0.7024999782443047
# Error validación 0.7731124814599752
# Exactitud validación 0.6937499800696969
#
#
#
# Iteración 32
# Error entrenamiento 0.8210386354476213
# Exactitud entrenamiento 0.6799999792128801
# Error validación 0.7641554567962885
# Exactitud validación 0.7074999827891588
#
#
#
# Iteración 33
# Error entrenamiento 0.7872692942619324
# Exactitud entrenamiento 0.6824999768286943
# Error validación 0.8497484102845192
# Exactitud validación 0.6574999857693911
#
#
#
# Iteración 34
# Error entrenamiento 0.7621446000412107
# Exactitud entrenamiento 0.6974999830126762
# Error validación 0.7195925740525126
# Exactitud validación 0.7287499774247408
#
#
#
# Iteración 35
# Error entrenamiento 0.765927224420011
# Exactitud entrenamiento 0.6949999751523137
# Error validación 0.7963230200111866
# Exactitud validación 0.6887499820441008
#
#
#
# Iteración 36
# Error entrenamiento 0.7178969439119101
# Exactitud entrenamiento 0.7199999801814556
# Error validación 0.7281695157289505
# Exactitud validación 0.7212499780580401
#
#
#
# Iteración 37
# Error entrenamiento 0.7092802599072456
# Exactitud entrenamiento 0.7262499816715717
# Error validación 0.7590098530054092
# Exactitud validación 0.6749999793246388
#
#
#
# Iteración 38
# Error entrenamiento 0.7026919545605779
# Exactitud entrenamiento 0.7499999813735485
# Error validación 0.852785250172019
# Exactitud validación 0.6487499810755253
#
#
#
# Iteración 39
# Error entrenamiento 0.8063572067767382
# Exactitud entrenamiento 0.6737499851733446
# Error validación 0.7292859917506576
# Exactitud validación 0.7212499817833304
#
#
#
# Iteración 40
# Error entrenamiento 0.7601489713415504
# Exactitud entrenamiento 0.6824999805539846
# Error validación 0.7192327668890357
# Exactitud validación 0.7187499795109034
#
#
#
# Iteración 41
# Error entrenamiento 0.7620783597230911
# Exactitud entrenamiento 0.7049999786540866
# Error validación 0.7179456036537886
# Exactitud validación 0.7224999824538827
#
#
#
# Iteración 42
# Error entrenamiento 0.7609323859214783
# Exactitud entrenamiento 0.7074999837204814
# Error validación 0.7001012293621898
# Exactitud validación 0.7112499792128801
#
#
#
# Iteración 43
# Error entrenamiento 0.7119175400584936
# Exactitud entrenamiento 0.7537499824538827
# Error validación 0.747149411123246
# Exactitud validación 0.7174999797716737
#
#
#
# Iteración 44
# Error entrenamiento 0.7074878290295601
# Exactitud entrenamiento 0.7212499864399433
# Error validación 0.7360835904255509
# Exactitud validación 0.6987499808892608
#
#
#
# Iteración 45
# Error entrenamiento 0.7099285498261452
# Exactitud entrenamiento 0.7362499823793769
# Error validación 0.7371925115585327
# Exactitud validación 0.7249999735504389
#
#
#
# Iteración 46
# Error entrenamiento 0.7690232805907726
# Exactitud entrenamiento 0.6937499791383743
# Error validación 0.7684237090870738
# Exactitud validación 0.6874999757856131
#
#
#
# Iteración 47
# Error entrenamiento 0.7914274660870433
# Exactitud entrenamiento 0.6787499785423279
# Error validación 0.8125461023300886
# Exactitud validación 0.663749985396862
#
#
#
# Iteración 48
# Error entrenamiento 0.7389801871031523
# Exactitud entrenamiento 0.7024999838322401
# Error validación 0.7191630350425839
# Exactitud validación 0.7274999748915434
#
#
#
# Iteración 49
# Error entrenamiento 0.7296519540250301
# Exactitud entrenamiento 0.7237499775364995
# Error validación 0.7344479952007532
# Exactitud validación 0.6937499847263098
#
#
#
# Iteración 50
# Error entrenamiento 0.7255246611312032
# Exactitud entrenamiento 0.7112499829381704
# Error validación 0.7479727934114635
# Exactitud validación 0.7037499779835343
#
#
#
# Iteración 51
# Error entrenamiento 0.7942578298971057
# Exactitud entrenamiento 0.6999999806284904
# Error validación 0.7464997004717588
# Exactitud validación 0.7199999755248427
#
#
#
# Iteración 52
# Error entrenamiento 0.7200147518888116
# Exactitud entrenamiento 0.7174999788403511
# Error validación 0.6770603484474123
# Exactitud validación 0.7299999846145511
#
#
#
# Iteración 53
# Error entrenamiento 0.7380442097783089
# Exactitud entrenamiento 0.7099999766796827
# Error validación 0.7400951548479497
# Exactitud validación 0.6987499799579382
#
#
#
# Iteración 54
# Error entrenamiento 0.7455082265660167
# Exactitud entrenamiento 0.6862499779090285
# Error validación 0.7320006107911468
# Exactitud validación 0.7149999868124723
#
#
#
# Iteración 55
# Error entrenamiento 0.6988821756094694
# Exactitud entrenamiento 0.7449999796226621
# Error validación 0.7238139221444726
# Exactitud validación 0.717499976977706
#
#
#
# Iteración 56
# Error entrenamiento 0.6861066641286016
# Exactitud entrenamiento 0.7274999776855111
# Error validación 0.7590752644464374
# Exactitud validación 0.714999983087182
#
#
#
# Iteración 57
# Error entrenamiento 0.7115510944277048
# Exactitud entrenamiento 0.7187499795109034
# Error validación 0.8004352552816272
# Exactitud validación 0.6987499808892608
#
#
#
# Iteración 58
# Error entrenamiento 0.6998157612979412
# Exactitud entrenamiento 0.7237499793991446
# Error validación 0.7311938288621604
# Exactitud validación 0.7324999747797847
#
#
#
# Iteración 59
# Error entrenamiento 0.6902525047771633
# Exactitud entrenamiento 0.7437499826774001
# Error validación 0.7343678623437881
# Exactitud validación 0.7237499887123704
#
#
#
# Iteración 60
# Error entrenamiento 0.6495050368830562
# Exactitud entrenamiento 0.7487499788403511
# Error validación 0.7632646933197975
# Exactitud validación 0.6849999791011214
#
#
#
# Iteración 61
# Error entrenamiento 0.7545027555897832
# Exactitud entrenamiento 0.6987499855458736
# Error validación 0.733622063882649
# Exactitud validación 0.7099999841302633
#
#
#
# Iteración 62
# Error entrenamiento 0.6752367159351707
# Exactitud entrenamiento 0.7524999808520079
# Error validación 0.7046491620130837
# Exactitud validación 0.7299999799579382
#
#
#
# Iteración 63
# Error entrenamiento 0.688566685654223
# Exactitud entrenamiento 0.7299999818205833
# Error validación 0.7106255465187132
# Exactitud validación 0.7224999777972698
#
#
#
# Iteración 64
# Error entrenamiento 0.6749945590272546
# Exactitud entrenamiento 0.7424999782815576
# Error validación 0.7286612521857023
# Exactitud validación 0.6949999807402492
#
#
#
# Iteración 65
# Error entrenamiento 0.6955946646630764
# Exactitud entrenamiento 0.7299999799579382
# Error validación 0.7331469273194671
# Exactitud validación 0.7049999814480543
#
#
#
# Iteración 66
# Error entrenamiento 0.6819562199525535
# Exactitud entrenamiento 0.7362499851733446
# Error validación 0.7442616187036037
# Exactitud validación 0.6924999840557575
#
#
#
# Iteración 67
# Error entrenamiento 0.6954174125567079
# Exactitud entrenamiento 0.7299999790266156
# Error validación 0.6702562114223838
# Exactitud validación 0.7524999789893627
#
#
#
# Iteración 68
# Error entrenamiento 0.6357295131310821
# Exactitud entrenamiento 0.7699999762699008
# Error validación 0.6972923660650849
# Exactitud validación 0.7199999820441008
#
#
#
# Iteración 69
# Error entrenamiento 0.6836676653474569
# Exactitud entrenamiento 0.7399999788030982
# Error validación 0.6803443487733603
# Exactitud validación 0.7362499814480543
#
#
#
# Iteración 70
# Error entrenamiento 0.6812403229996562
# Exactitud entrenamiento 0.7412499822676182
# Error validación 0.7168197527062148
# Exactitud validación 0.7212499845772982
#
#
#
# Iteración 71
# Error entrenamiento 0.6983420075848699
# Exactitud entrenamiento 0.7237499821931124
# Error validación 0.7063649762421846
# Exactitud validación 0.7287499792873859
#
#
#
# Iteración 72
# Error entrenamiento 0.6509111002087593
# Exactitud entrenamiento 0.7424999829381704
# Error validación 0.6649508504197001
# Exactitud validación 0.7587499851360917
#
#
#
# Iteración 73
# Error entrenamiento 0.7008677311241627
# Exactitud entrenamiento 0.7349999761208892
# Error validación 0.7239782805554569
# Exactitud validación 0.7049999814480543
#
#
#
# Iteración 74
# Error entrenamiento 0.7864252794533968
# Exactitud entrenamiento 0.6999999759718776
# Error validación 0.6269933171570301
# Exactitud validación 0.7449999768286943
#
#
#
# Iteración 75
# Error entrenamiento 0.6825124621391296
# Exactitud entrenamiento 0.7337499838322401
# Error validación 0.7111035571433604
# Exactitud validación 0.724999981932342
#
#
#
# Iteración 76
# Error entrenamiento 0.68528663367033
# Exactitud entrenamiento 0.7412499785423279
# Error validación 0.626287457998842
# Exactitud validación 0.7687499802559614
#
#
#
# Iteración 77
# Error entrenamiento 0.6864285217598081
# Exactitud entrenamiento 0.7262499826028943
# Error validación 0.7104836483485997
# Exactitud validación 0.7312499769032001
#
#
#
# Iteración 78
# Error entrenamiento 0.700981370639056
# Exactitud entrenamiento 0.717499976977706
# Error validación 0.718029448762536
# Exactitud validación 0.7149999877437949
#
#
#
# Iteración 79
# Error entrenamiento 0.6484621725976467
# Exactitud entrenamiento 0.7237499793991446
# Error validación 0.7352171884849668
# Exactitud validación 0.7224999815225601
#
#
#
# Iteración 80
# Error entrenamiento 0.6643736064434052
# Exactitud entrenamiento 0.7437499798834324
# Error validación 0.6887188656255603
# Exactitud validación 0.7262499816715717
#
#
#
# Iteración 81
# Error entrenamiento 0.6771758613176644
# Exactitud entrenamiento 0.7287499802187085
# Error validación 0.6947372937574983
# Exactitud validación 0.7362499758601189
#
#
#
# Iteración 82
# Error entrenamiento 0.6390141951851547
# Exactitud entrenamiento 0.757499978877604
# Error validación 0.7447272278368473
# Exactitud validación 0.7274999860674143
#
#
#
# Iteración 83
# Error entrenamiento 0.7336576404049993
# Exactitud entrenamiento 0.7262499770149589
# Error validación 0.6877435320056975
# Exactitud validación 0.7299999799579382
#
#
#
# Iteración 84
# Error entrenamiento 0.6235144305974245
# Exactitud entrenamiento 0.7487499862909317
# Error validación 0.6627346407622099
# Exactitud validación 0.7224999833852053
#
#
#
# Iteración 85
# Error entrenamiento 0.6279333950951695
# Exactitud entrenamiento 0.7587499786168337
# Error validación 0.7083173068240285
# Exactitud validación 0.7249999763444066
#
#
#
# Iteración 86
# Error entrenamiento 0.6636659372597933
# Exactitud entrenamiento 0.7399999760091305
# Error validación 0.6342622954398394
# Exactitud validación 0.753749979659915
#
#
#
# Iteración 87
# Error entrenamiento 0.6304756887257099
# Exactitud entrenamiento 0.7549999821931124
# Error validación 0.7361270980909467
# Exactitud validación 0.7199999811127782
#
#
#
# Iteración 88
# Error entrenamiento 0.73506687162444
# Exactitud entrenamiento 0.7299999790266156
# Error validación 0.7017586850561202
# Exactitud validación 0.7274999804794788
#
#
#
# Iteración 89
# Error entrenamiento 0.701457261107862
# Exactitud entrenamiento 0.7049999805167317
# Error validación 0.6761536332778633
# Exactitud validación 0.7412499748170376
#
#
#
# Iteración 90
# Error entrenamiento 0.695463951677084
# Exactitud entrenamiento 0.7224999777972698
# Error validación 0.6401453288272023
# Exactitud validación 0.7399999815970659
#
#
#
# Iteración 91
# Error entrenamiento 0.7193316100165248
# Exactitud entrenamiento 0.7212499808520079
# Error validación 0.7094301925972104
# Exactitud validación 0.7262499760836363
#
#
#
# Iteración 92
# Error entrenamiento 0.681636375375092
# Exactitud entrenamiento 0.7199999783188105
# Error validación 0.7455078484490514
# Exactitud validación 0.7012499812990427
#
#
#
# Iteración 93
# Error entrenamiento 0.657801566645503
# Exactitud entrenamiento 0.7424999801442027
# Error validación 0.6234279864002019
# Exactitud validación 0.7512499820441008
#
#
#
# Iteración 94
# Error entrenamiento 0.610264029353857
# Exactitud entrenamiento 0.7562499763444066
# Error validación 0.705864345189184
# Exactitud validación 0.719999979250133
#
#
#
# Iteración 95
# Error entrenamiento 0.747571025043726
# Exactitud entrenamiento 0.6949999835342169
# Error validación 0.6694129593670368
# Exactitud validación 0.7412499785423279
#
#
#
# Iteración 96
# Error entrenamiento 0.6576989870518446
# Exactitud entrenamiento 0.7512499764561653
# Error validación 0.6919493549503386
# Exactitud validación 0.741249980404973
#
#
#
# Iteración 97
# Error entrenamiento 0.6422385275363922
# Exactitud entrenamiento 0.7649999782443047
# Error validación 0.6342703867703676
# Exactitud validación 0.7712499722838402
#
#
#
# Iteración 98
# Error entrenamiento 0.6315547428093851
# Exactitud entrenamiento 0.7624999806284904
# Error validación 0.6330380830913782
# Exactitud validación 0.7662499789148569
#
#
#
# Iteración 99
# Error entrenamiento 0.6380506474524736
# Exactitud entrenamiento 0.748749976977706
# Error validación 0.6410132646560669
# Exactitud validación 0.7499999813735485
#
#
#
# Iteración 100
# Error entrenamiento 0.6515879305079579
# Exactitud entrenamiento 0.7424999820068479
# Error validación 0.6120693325065076
# Exactitud validación 0.7474999818950891
#
#
#
# Iteración 101
# Error entrenamiento 0.6667511034756899
# Exactitud entrenamiento 0.741249980404973
# Error validación 0.672984030097723
# Exactitud validación 0.7487499788403511
#
#
#
# Iteración 102
# Error entrenamiento 0.6469138851389289
# Exactitud entrenamiento 0.7474999781697989
# Error validación 0.6859916914254427
# Exactitud validación 0.7424999764189124
#
#
#
# Iteración 103
# Error entrenamiento 0.6038698330521584
# Exactitud entrenamiento 0.7587499786168337
# Error validación 0.6112755672074854
# Exactitud validación 0.7637499775737524
#
#
#
# Iteración 104
# Error entrenamiento 0.6290291007608175
# Exactitud entrenamiento 0.7649999782443047
# Error validación 0.6358754863031209
# Exactitud validación 0.7449999805539846
#
#
#
# Iteración 105
# Error entrenamiento 0.6428231401368976
# Exactitud entrenamiento 0.743749980814755
# Error validación 0.6644605938345194
# Exactitud validación 0.7462499812245369
#
#
#
# Iteración 106
# Error entrenamiento 0.5770113305188715
# Exactitud entrenamiento 0.7987499758601189
# Error validación 0.6580863855779171
# Exactitud validación 0.7374999793246388
#
#
#
# Iteración 107
# Error entrenamiento 0.5475382884033024
# Exactitud entrenamiento 0.793749981559813
# Error validación 0.7034363951534033
# Exactitud validación 0.7237499793991446
#
#
#
# Iteración 108
# Error entrenamiento 0.5938245952129364
# Exactitud entrenamiento 0.7749999798834324
# Error validación 0.5925179002806544
# Exactitud validación 0.7762499768286943
#
#
#
# Iteración 109
# Error entrenamiento 0.5795295159332454
# Exactitud entrenamiento 0.7812499767169356
# Error validación 0.6272814790718257
# Exactitud validación 0.7512499783188105
#
#
#
# Iteración 110
# Error entrenamiento 0.5925824451260269
# Exactitud entrenamiento 0.7699999827891588
# Error validación 0.6534247361123562
# Exactitud validación 0.7437499761581421
#
#
#
# Iteración 111
# Error entrenamiento 0.5983105874620378
# Exactitud entrenamiento 0.7837499771267176
# Error validación 0.6062565557658672
# Exactitud validación 0.7587499767541885
#
#
#
# Iteración 112
# Error entrenamiento 0.6417582035064697
# Exactitud entrenamiento 0.751249979250133
# Error validación 0.6037181783467531
# Exactitud validación 0.7574999779462814
#
#
#
# Iteración 113
# Error entrenamiento 0.6016355096362531
# Exactitud entrenamiento 0.7837499789893627
# Error validación 0.668745425529778
# Exactitud validación 0.7349999798461795
#
#
#
# Iteración 114
# Error entrenamiento 0.6461498849093914
# Exactitud entrenamiento 0.7512499801814556
# Error validación 0.5959457401186228
# Exactitud validación 0.7549999840557575
#
#
#
# Iteración 115
# Error entrenamiento 0.6489257165230811
# Exactitud entrenamiento 0.7599999811500311
# Error validación 0.634735094383359
# Exactitud validación 0.7349999751895666
#
#
#
# Iteración 116
# Error entrenamiento 0.6687618354335427
# Exactitud entrenamiento 0.7499999813735485
# Error validación 0.6390804620459676
# Exactitud validación 0.7337499801069498
#
#
#
# Iteración 117
# Error entrenamiento 0.5147309666499496
# Exactitud entrenamiento 0.8024999760091305
# Error validación 0.6100418604910374
# Exactitud validación 0.7862499784678221
#
#
#
# Iteración 118
# Error entrenamiento 0.6297141844406724
# Exactitud entrenamiento 0.767499977722764
# Error validación 0.6239256821572781
# Exactitud validación 0.7574999779462814
#
#
#
# Iteración 119
# Error entrenamiento 0.5992884179577231
# Exactitud entrenamiento 0.7512499801814556
# Error validación 0.6120917578227818
# Exactitud validación 0.7549999766051769
#
#
#
# Iteración 120
# Error entrenamiento 0.5397423477843404
# Exactitud entrenamiento 0.7824999801814556
# Error validación 0.5733709265477955
# Exactitud validación 0.772499980404973
#
#
#
# Error test 0.5733709265477955
# Exactitud test 0.772499980404973

# %% [markdown]
# Con la versión de primer orden se ha conseguido una mejor exactitud, pero sigue estando lejos del 99.9% que los autores de MAML sugieren en la publicación original. No obstante, el número de iteraciones usado es bajo, ya que habitualmente se suelen usar entre 10.000 y 20.000, aquí se han usado 100. Podría probarse otro extractor de características, con el fin de comprobar si mejora la calidad del ajuste.
#
#   Por ejemplo, probando el el extractor `OmniglotFC` proporcionado por learn2learn:

# %%
config["iteraciones_entrenamiento"] = 1000
config["verbose"] = 0

modulo_fnn = l2l.vision.models.OmniglotFC(28*28, n_ways)

modulo_fnn.to(dispositivo) 

MAML_1st = l2l.algorithms.MAML(modulo_fnn, tam_paso_maml, first_order=True)
optimizador_1st = torch.optim.Adam(MAML_1st.parameters(), lr = tam_paso_adam)

entrenamiento(MAML_1st, tareas_omniglot, optimizador_1st, funcion_perdida, dispositivo, config)
# Out:
# Iteración 1
# Error entrenamiento 1.5654605031013489
# Exactitud entrenamiento 0.47624998912215233
# Error validación 1.563189648091793
# Exactitud validación 0.5012499894946814
#
#
#
# Iteración 11
# Error entrenamiento 0.7607728745788336
# Exactitud entrenamiento 0.7349999789148569
# Error validación 0.7851143470034003
# Exactitud validación 0.7124999780207872
#
#
#
# Iteración 21
# Error entrenamiento 0.6471819500438869
# Exactitud entrenamiento 0.7612499762326479
# Error validación 0.7094968408346176
# Exactitud validación 0.7424999829381704
#
#
#
# Iteración 31
# Error entrenamiento 0.5892453193664551
# Exactitud entrenamiento 0.8099999772384763
# Error validación 0.5972732221707702
# Exactitud validación 0.7874999772757292
#
#
#
# Iteración 41
# Error entrenamiento 0.5655265841633081
# Exactitud entrenamiento 0.8037499748170376
# Error validación 0.574047370813787
# Exactitud validación 0.7912499792873859
#
#
#
# Iteración 51
# Error entrenamiento 0.5054878653027117
# Exactitud entrenamiento 0.8324999753385782
# Error validación 0.5621646400541067
# Exactitud validación 0.7974999826401472
#
#
#
# Iteración 61
# Error entrenamiento 0.5596690685488284
# Exactitud entrenamiento 0.8199999835342169
# Error validación 0.5184107527602464
# Exactitud validación 0.8199999798089266
#
#
#
# Iteración 71
# Error entrenamiento 0.47049546521157026
# Exactitud entrenamiento 0.8312499709427357
# Error validación 0.529654330573976
# Exactitud validación 0.8187499772757292
#
#
#
# Iteración 81
# Error entrenamiento 0.49531986052170396
# Exactitud entrenamiento 0.8199999742209911
# Error validación 0.5192622891627252
# Exactitud validación 0.8274999838322401
#
#
#
# Iteración 91
# Error entrenamiento 0.505705479066819
# Exactitud entrenamiento 0.8249999759718776
# Error validación 0.5402893675491214
# Exactitud validación 0.8062499770894647
#
#
#
# Iteración 101
# Error entrenamiento 0.4393826788291335
# Exactitud entrenamiento 0.8499999772757292
# Error validación 0.5158007938880473
# Exactitud validación 0.816249979659915
#
#
#
# Iteración 111
# Error entrenamiento 0.4750325954519212
# Exactitud entrenamiento 0.8349999822676182
# Error validación 0.5283169912872836
# Exactitud validación 0.8399999774992466
#
#
#
# Iteración 121
# Error entrenamiento 0.5025517891626805
# Exactitud entrenamiento 0.8237499762326479
# Error validación 0.4842337805312127
# Exactitud validación 0.836249977350235
#
#
#
# Iteración 131
# Error entrenamiento 0.3722936473786831
# Exactitud entrenamiento 0.883749982342124
# Error validación 0.4492412854451686
# Exactitud validación 0.8437499776482582
#
#
#
# Iteración 141
# Error entrenamiento 0.4589477446861565
# Exactitud entrenamiento 0.8474999759346247
# Error validación 0.45547646889463067
# Exactitud validación 0.8349999748170376
#
#
#
# Iteración 151
# Error entrenamiento 0.4081143990624696
# Exactitud entrenamiento 0.8599999733269215
# Error validación 0.4332652532029897
# Exactitud validación 0.8524999748915434
#
#
#
# Iteración 161
# Error entrenamiento 0.36708077031653374
# Exactitud entrenamiento 0.8737499788403511
# Error validación 0.3777263902593404
# Exactitud validación 0.8787499759346247
#
#
#
# Iteración 171
# Error entrenamiento 0.35743412049487233
# Exactitud entrenamiento 0.8887499775737524
# Error validación 0.4047353045316413
# Exactitud validación 0.8737499788403511
#
#
#
# Iteración 181
# Error entrenamiento 0.33968120184727013
# Exactitud entrenamiento 0.8849999718368053
# Error validación 0.4100587728898972
# Exactitud validación 0.8699999805539846
#
#
#
# Iteración 191
# Error entrenamiento 0.33487888891249895
# Exactitud entrenamiento 0.8787499740719795
# Error validación 0.3617036647628993
# Exactitud validación 0.8762499783188105
#
#
#
# Iteración 201
# Error entrenamiento 0.37479018489830196
# Exactitud entrenamiento 0.8762499801814556
# Error validación 0.4684331966564059
# Exactitud validación 0.8512499816715717
#
#
#
# Iteración 211
# Error entrenamiento 0.3853668642695993
# Exactitud entrenamiento 0.8737499788403511
# Error validación 0.3893716288730502
# Exactitud validación 0.8699999768286943
#
#
#
# Iteración 221
# Error entrenamiento 0.36489246878772974
# Exactitud entrenamiento 0.8712499793618917
# Error validación 0.4018825951498002
# Exactitud validación 0.866249980404973
#
#
#
# Iteración 231
# Error entrenamiento 0.3100233192089945
# Exactitud entrenamiento 0.8974999748170376
# Error validación 0.3332817545160651
# Exactitud validación 0.8874999824911356
#
#
#
# Iteración 241
# Error entrenamiento 0.3773842337541282
# Exactitud entrenamiento 0.8737499807029963
# Error validación 0.3999722426524386
# Exactitud validación 0.862499974668026
#
#
#
# Iteración 251
# Error entrenamiento 0.35864888108335435
# Exactitud entrenamiento 0.8774999734014273
# Error validación 0.3671982328523882
# Exactitud validación 0.8737499788403511
#
#
#
# Iteración 261
# Error entrenamiento 0.34571219701319933
# Exactitud entrenamiento 0.8849999736994505
# Error validación 0.44922455260530114
# Exactitud validación 0.8649999778717756
#
#
#
# Iteración 271
# Error entrenamiento 0.33502290514297783
# Exactitud entrenamiento 0.8862499762326479
# Error validación 0.3333633776055649
# Exactitud validación 0.901249973103404
#
#
#
# Iteración 281
# Error entrenamiento 0.32000724296085536
# Exactitud entrenamiento 0.8999999724328518
# Error validación 0.4246224514208734
# Exactitud validación 0.858749981969595
#
#
#
# Iteración 291
# Error entrenamiento 0.3438352330122143
# Exactitud entrenamiento 0.8837499786168337
# Error validación 0.4022867048624903
# Exactitud validación 0.8662499766796827
#
#
#
# Iteración 301
# Error entrenamiento 0.2925003906711936
# Exactitud entrenamiento 0.9024999756366014
# Error validación 0.3371350042289123
# Exactitud validación 0.892499977722764
#
#
#
# Iteración 311
# Error entrenamiento 0.3004393645678647
# Exactitud entrenamiento 0.8862499762326479
# Error validación 0.37601723449188285
# Exactitud validación 0.8874999824911356
#
#
#
# Iteración 321
# Error entrenamiento 0.3062394653679803
# Exactitud entrenamiento 0.8974999766796827
# Error validación 0.4121970902197063
# Exactitud validación 0.8687499724328518
#
#
#
# Iteración 331
# Error entrenamiento 0.2755126861156896
# Exactitud entrenamiento 0.9162499774247408
# Error validación 0.29521181096788496
# Exactitud validación 0.8899999763816595
#
#
#
# Iteración 341
# Error entrenamiento 0.29074064071755856
# Exactitud entrenamiento 0.8987499792128801
# Error validación 0.29686228674836457
# Exactitud validación 0.9087499771267176
#
#
#
# Iteración 351
# Error entrenamiento 0.32649838738143444
# Exactitud entrenamiento 0.8962499834597111
# Error validación 0.3795502004213631
# Exactitud validación 0.8599999751895666
#
#
#
# Iteración 361
# Error entrenamiento 0.32939288206398487
# Exactitud entrenamiento 0.8774999808520079
# Error validación 0.3816404880490154
# Exactitud validación 0.872499980032444
#
#
#
# Iteración 371
# Error entrenamiento 0.39856653357855976
# Exactitud entrenamiento 0.864999970421195
# Error validación 0.3471105901990086
# Exactitud validación 0.8687499798834324
#
#
#
# Iteración 381
# Error entrenamiento 0.2595411315560341
# Exactitud entrenamiento 0.9137499798089266
# Error validación 0.3780564966145903
# Exactitud validación 0.8837499748915434
#
#
#
# Iteración 391
# Error entrenamiento 0.38298609759658575
# Exactitud entrenamiento 0.8812499810010195
# Error validación 0.27450159122236073
# Exactitud validación 0.8987499810755253
#
#
#
# Iteración 401
# Error entrenamiento 0.27646512794308364
# Exactitud entrenamiento 0.9137499760836363
# Error validación 0.30281567375641316
# Exactitud validación 0.8999999761581421
#
#
#
# Iteración 411
# Error entrenamiento 0.26063545630313456
# Exactitud entrenamiento 0.9062499776482582
# Error validación 0.4413638819241896
# Exactitud validación 0.8512499835342169
#
#
#
# Iteración 421
# Error entrenamiento 0.26333610169240274
# Exactitud entrenamiento 0.9062499795109034
# Error validación 0.320046350476332
# Exactitud validación 0.9062499795109034
#
#
#
# Iteración 431
# Error entrenamiento 0.2547725203912705
# Exactitud entrenamiento 0.9112499803304672
# Error validación 0.2744143813615665
# Exactitud validación 0.9062499795109034
#
#
#
# Iteración 441
# Error entrenamiento 0.23231267248047516
# Exactitud entrenamiento 0.9162499830126762
# Error validación 0.2964680506847799
# Exactitud validación 0.9024999774992466
#
#
#
# Iteración 451
# Error entrenamiento 0.24756460427306592
# Exactitud entrenamiento 0.9174999762326479
# Error validación 0.30297596828313544
# Exactitud validación 0.898749977350235
#
#
#
# Iteración 461
# Error entrenamiento 0.2299075028859079
# Exactitud entrenamiento 0.9249999783933163
# Error validación 0.2986548657063395
# Exactitud validación 0.8962499722838402
#
#
#
# Iteración 471
# Error entrenamiento 0.2953368490561843
# Exactitud entrenamiento 0.8912499751895666
# Error validación 0.2969327208120376
# Exactitud validación 0.8812499791383743
#
#
#
# Iteración 481
# Error entrenamiento 0.25808218243764713
# Exactitud entrenamiento 0.9162499830126762
# Error validación 0.32511169370263815
# Exactitud validación 0.8774999771267176
#
#
#
# Iteración 491
# Error entrenamiento 0.2803379651159048
# Exactitud entrenamiento 0.8987499754875898
# Error validación 0.3145948613382643
# Exactitud validación 0.8974999748170376
#
#
#
# Iteración 501
# Error entrenamiento 0.31038588425144553
# Exactitud entrenamiento 0.9024999774992466
# Error validación 0.28568900073878467
# Exactitud validación 0.9087499789893627
#
#
#
# Iteración 511
# Error entrenamiento 0.19881878671003506
# Exactitud entrenamiento 0.941249979659915
# Error validación 0.355335449334234
# Exactitud validación 0.886249978095293
#
#
#
# Iteración 521
# Error entrenamiento 0.2178008709452115
# Exactitud entrenamiento 0.941249979659915
# Error validación 0.3431436289101839
# Exactitud validación 0.8824999798089266
#
#
#
# Iteración 531
# Error entrenamiento 0.21880224120104685
# Exactitud entrenamiento 0.9349999837577343
# Error validación 0.3091572029516101
# Exactitud validación 0.8974999692291021
#
#
#
# Iteración 541
# Error entrenamiento 0.25232250237604603
# Exactitud entrenamiento 0.909999979659915
# Error validación 0.2732937686960213
# Exactitud validación 0.903749980032444
#
#
#
# Iteración 551
# Error entrenamiento 0.24732839118223637
# Exactitud entrenamiento 0.9137499779462814
# Error validación 0.31218709354288876
# Exactitud validación 0.8899999782443047
#
#
#
# Iteración 561
# Error entrenamiento 0.23645961633883417
# Exactitud entrenamiento 0.9224999807775021
# Error validación 0.2721249059541151
# Exactitud validación 0.9049999732524157
#
#
#
# Iteración 571
# Error entrenamiento 0.20933396110194735
# Exactitud entrenamiento 0.9249999821186066
# Error validación 0.3101616465719417
# Exactitud validación 0.8849999774247408
#
#
#
# Iteración 581
# Error entrenamiento 0.2840263165999204
# Exactitud entrenamiento 0.9112499747425318
# Error validación 0.3231848607538268
# Exactitud validación 0.8974999766796827
#
#
#
# Iteración 591
# Error entrenamiento 0.312653822125867
# Exactitud entrenamiento 0.9074999764561653
# Error validación 0.39912670967169106
# Exactitud validación 0.8612499758601189
#
#
#
# Iteración 601
# Error entrenamiento 0.24799901980441064
# Exactitud entrenamiento 0.9112499803304672
# Error validación 0.27300300408387557
# Exactitud validación 0.9124999791383743
#
#
#
# Iteración 611
# Error entrenamiento 0.2189158067922108
# Exactitud entrenamiento 0.9312499761581421
# Error validación 0.4195129706058651
# Exactitud validación 0.8649999741464853
#
#
#
# Iteración 621
# Error entrenamiento 0.3317757615004666
# Exactitud entrenamiento 0.8837499804794788
# Error validación 0.3569755838252604
# Exactitud validación 0.886249978095293
#
#
#
# Iteración 631
# Error entrenamiento 0.3040921092033386
# Exactitud entrenamiento 0.912499975413084
# Error validación 0.2970638027181849
# Exactitud validación 0.8937499821186066
#
#
#
# Iteración 641
# Error entrenamiento 0.2913273691665381
# Exactitud entrenamiento 0.9074999801814556
# Error validación 0.2987149559194222
# Exactitud validación 0.8962499778717756
#
#
#
# Iteración 651
# Error entrenamiento 0.283515892457217
# Exactitud entrenamiento 0.8962499815970659
# Error validación 0.34231381432618946
# Exactitud validación 0.8887499738484621
#
#
#
# Iteración 661
# Error entrenamiento 0.2603756388416514
# Exactitud entrenamiento 0.9187499787658453
# Error validación 0.3391658957116306
# Exactitud validación 0.8974999822676182
#
#
#
# Iteración 671
# Error entrenamiento 0.22606808692216873
# Exactitud entrenamiento 0.9199999794363976
# Error validación 0.31585219711996615
# Exactitud validación 0.8937499709427357
#
#
#
# Iteración 681
# Error entrenamiento 0.24873760348418728
# Exactitud entrenamiento 0.9199999775737524
# Error validación 0.3456304252613336
# Exactitud validación 0.8949999753385782
#
#
#
# Iteración 691
# Error entrenamiento 0.24137565662385896
# Exactitud entrenamiento 0.9274999797344208
# Error validación 0.2884755616541952
# Exactitud validación 0.8987499754875898
#
#
#
# Iteración 701
# Error entrenamiento 0.23872230399865657
# Exactitud entrenamiento 0.9174999799579382
# Error validación 0.369598156074062
# Exactitud validación 0.8812499828636646
#
#
#
# Iteración 711
# Error entrenamiento 0.2705804544966668
# Exactitud entrenamiento 0.9074999801814556
# Error validación 0.3355474466807209
# Exactitud validación 0.9012499768286943
#
#
#
# Iteración 721
# Error entrenamiento 0.24087637462071143
# Exactitud entrenamiento 0.9149999748915434
# Error validación 0.3399094631895423
# Exactitud validación 0.8949999790638685
#
#
#
# Iteración 731
# Error entrenamiento 0.2201529707526788
# Exactitud entrenamiento 0.9337499812245369
# Error validación 0.42400398035533726
# Exactitud validación 0.8537499774247408
#
#
#
# Iteración 741
# Error entrenamiento 0.3352282462292351
# Exactitud entrenamiento 0.8849999811500311
# Error validación 0.37325628788676113
# Exactitud validación 0.8699999786913395
#
#
#
# Iteración 751
# Error entrenamiento 0.24034085148014128
# Exactitud entrenamiento 0.9224999807775021
# Error validación 0.32430919725447893
# Exactitud validación 0.8962499797344208
#
#
#
# Iteración 761
# Error entrenamiento 0.22769108242937364
# Exactitud entrenamiento 0.914999982342124
# Error validación 0.2762692703399807
# Exactitud validación 0.8999999742954969
#
#
#
# Iteración 771
# Error entrenamiento 0.2509722497779876
# Exactitud entrenamiento 0.9262499827891588
# Error validación 0.31242192280478776
# Exactitud validación 0.9024999812245369
#
#
#
# Iteración 781
# Error entrenamiento 0.24463920178823173
# Exactitud entrenamiento 0.9162499718368053
# Error validación 0.36772787221707404
# Exactitud validación 0.8787499740719795
#
#
#
# Iteración 791
# Error entrenamiento 0.20801452652085572
# Exactitud entrenamiento 0.9312499780207872
# Error validación 0.4215808786684647
# Exactitud validación 0.8537499736994505
#
#
#
# Iteración 801
# Error entrenamiento 0.2748130821273662
# Exactitud entrenamiento 0.9112499821931124
# Error validación 0.3182272204430774
# Exactitud validación 0.8912499733269215
#
#
#
# Iteración 811
# Error entrenamiento 0.23489905579481274
# Exactitud entrenamiento 0.9312499780207872
# Error validación 0.34435555519303307
# Exactitud validación 0.8949999753385782
#
#
#
# Iteración 821
# Error entrenamiento 0.18899659055750817
# Exactitud entrenamiento 0.9424999821931124
# Error validación 0.2720164875499904
# Exactitud validación 0.9087499752640724
#
#
#
# Iteración 831
# Error entrenamiento 0.20625585422385484
# Exactitud entrenamiento 0.9237499758601189
# Error validación 0.35561359400162473
# Exactitud validación 0.898749977350235
#
#
#
# Iteración 841
# Error entrenamiento 0.26201741106342524
# Exactitud entrenamiento 0.9187499769032001
# Error validación 0.2457614847808145
# Exactitud validación 0.9262499790638685
#
#
#
# Iteración 851
# Error entrenamiento 0.2601459337165579
# Exactitud entrenamiento 0.9074999783188105
# Error validación 0.30751830723602325
# Exactitud validación 0.9024999756366014
#
#
#
# Iteración 861
# Error entrenamiento 0.252392559137661
# Exactitud entrenamiento 0.9287499766796827
# Error validación 0.3538945948239416
# Exactitud validación 0.8762499801814556
#
#
#
# Iteración 871
# Error entrenamiento 0.18045468360651284
# Exactitud entrenamiento 0.9387499820441008
# Error validación 0.4301454139640555
# Exactitud validación 0.8512499816715717
#
#
#
# Iteración 881
# Error entrenamiento 0.23531987908063456
# Exactitud entrenamiento 0.9199999775737524
# Error validación 0.29384834854863584
# Exactitud validación 0.9012499805539846
#
#
#
# Iteración 891
# Error entrenamiento 0.1911023568827659
# Exactitud entrenamiento 0.9449999798089266
# Error validación 0.24740470945835114
# Exactitud validación 0.9037499744445086
#
#
#
# Iteración 901
# Error entrenamiento 0.21220116142649204
# Exactitud entrenamiento 0.9312499817460775
# Error validación 0.31999423436354846
# Exactitud validación 0.8849999774247408
#
#
#
# Iteración 911
# Error entrenamiento 0.21991521900054067
# Exactitud entrenamiento 0.9262499827891588
# Error validación 0.2887920087669045
# Exactitud validación 0.893749974668026
#
#
#
# Iteración 921
# Error entrenamiento 0.2103546948346775
# Exactitud entrenamiento 0.9299999792128801
# Error validación 0.24275921494700015
# Exactitud validación 0.9124999772757292
#
#
#
# Iteración 931
# Error entrenamiento 0.20034629601286724
# Exactitud entrenamiento 0.9424999859184027
# Error validación 0.340992261772044
# Exactitud validación 0.8899999801069498
#
#
#
# Iteración 941
# Error entrenamiento 0.18388795154169202
# Exactitud entrenamiento 0.9499999824911356
# Error validación 0.25159129907842726
# Exactitud validación 0.9187499806284904
#
#
#
# Iteración 951
# Error entrenamiento 0.20896779920440167
# Exactitud entrenamiento 0.9249999802559614
# Error validación 0.3247236897004768
# Exactitud validación 0.8937499728053808
#
#
#
# Iteración 961
# Error entrenamiento 0.19572256223182194
# Exactitud entrenamiento 0.9274999853223562
# Error validación 0.2906150279159192
# Exactitud validación 0.9199999794363976
#
#
#
# Iteración 971
# Error entrenamiento 0.15792131412308663
# Exactitud entrenamiento 0.951249985024333
# Error validación 0.2886366582242772
# Exactitud validación 0.9049999807029963
#
#
#
# Iteración 981
# Error entrenamiento 0.18001649517100304
# Exactitud entrenamiento 0.939999982714653
# Error validación 0.294475807226263
# Exactitud validación 0.9024999793618917
#
#
#
# Iteración 991
# Error entrenamiento 0.22201924654655159
# Exactitud entrenamiento 0.9287499822676182
# Error validación 0.32419474952621385
# Exactitud validación 0.8912499751895666
#
#
#
# Error test 0.29740491922711954
# Exactitud test 0.8974999766796827

# %% [markdown]
# Se ha obtenido con 1.000 iteraciones un 89.75% de exactitud con 5-way, 5-shot y una iteración de adaptación.

# %% [markdown]
# El bloque `OmniglotFC` está compuesto por:

# %%
l2l.vision.models.OmniglotFC(28 ** 2, n_ways)
# Out:
# OmniglotFC(
#   (features): Sequential(
#     (0): Flatten()
#     (1): Sequential(
#       (0): LinearBlock(
#         (relu): ReLU()
#         (normalize): BatchNorm1d(256, eps=0.001, momentum=0.999, affine=True, track_running_stats=False)
#         (linear): Linear(in_features=784, out_features=256, bias=True)
#       )
#       (1): LinearBlock(
#         (relu): ReLU()
#         (normalize): BatchNorm1d(128, eps=0.001, momentum=0.999, affine=True, track_running_stats=False)
#         (linear): Linear(in_features=256, out_features=128, bias=True)
#       )
#       (2): LinearBlock(
#         (relu): ReLU()
#         (normalize): BatchNorm1d(64, eps=0.001, momentum=0.999, affine=True, track_running_stats=False)
#         (linear): Linear(in_features=128, out_features=64, bias=True)
#       )
#       (3): LinearBlock(
#         (relu): ReLU()
#         (normalize): BatchNorm1d(64, eps=0.001, momentum=0.999, affine=True, track_running_stats=False)
#         (linear): Linear(in_features=64, out_features=64, bias=True)
#       )
#     )
#   )
#   (classifier): Linear(in_features=64, out_features=5, bias=True)
# )
